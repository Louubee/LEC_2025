# %% [markdown]
# # Config

# %%
import pandas as pd
import json, requests, csv
from module.my_module_ import *
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from time import sleep
from bs4 import BeautifulSoup as bs
from urllib.request import Request, urlopen
import module.my_module_
# Out:
# ['ActionChains', 'By', 'EC', 'GetAllMatches', 'GetData', 'GetDataMatch', 'GetDataTimeline', 'GetDictTournamenent', 'GetPuuid', 'Options', 'Request', 'WebDriverWait', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'api_key', 'bs', 'csv', 'headers', 'insert_SQL', 'json', 'keys', 'liste_match', 'make_request_max_limit', 'os', 'pd', 'psycopg2', 'requests', 'sleep', 'time', 'tqdm', 'urlopen', 'webdriver']

# %% [markdown]
# # Main

# %%
api_key=""
#Ouvertur du fichier keys.json
with open("./config/keys.json") as keys:
    api_key=json.load(keys)['api_key']
headers={
    'X-Riot-Token': api_key
}

# %%
#Initialisation
conn = psycopg2.connect(
    dbname="db_lol",
    user="postgres",
    password="root",
    host="localhost"
    )
cur = conn.cursor()
'''
df=GetDictTournamenent("https://lolpros.gg/leagues/LEC/lec-winter-season-2025)")
print(df.head(5))
'''
liste_matche=[]
df = pd.read_csv("./output/dictionnaire.csv")  # Remplace par le bon chemin

#Puuid 
for i in range (0,len(df)):
    if not df["gameName"][i] :
        continue
    else:   
        gameName=str(df["gameName"][i])
        print(gameName)
        tagLine=str(df["tagLine"][i])
        Player=df["Player"][i]
        Team=df["Team"][i]
        puuid=GetPuuid(gameName,tagLine,api_key) 
        df.at[i, "puuid"] = puuid
        liste_matche=liste_match(puuid,api_key)
        GetData(Player,Team,puuid,liste_matche,api_key) # Si pas de match, on skip



print("fini")
# Out:
# Isagi Yoichi
# Statut HTTP reçu: 200
# Statut HTTP reçu: 200
# Statut HTTP reçu: 200
# EUW1_7298206181
# Game N° 1
# EUW1_7298206181
# 1
# Statut HTTP reçu: 200
# EUW1_7298122208
# Game N° 2
# EUW1_7298122208
# 1
# Statut HTTP reçu: 200
# EUW1_7298059187
# Game N° 3
# EUW1_7298059187
# 1
# Statut HTTP reçu: 200
# EUW1_7296993217
# Game N° 4
# EUW1_7296993217
# 0
# Statut HTTP reçu: 200
# EUW1_7296809698
# Game N° 5
# EUW1_7296809698
# 1
# Statut HTTP reçu: 200
# EUW1_7296134505
# Game N° 6
# EUW1_7296134505
# 1
# Statut HTTP reçu: 200
# EUW1_7295957600
# Game N° 7
# EUW1_7295957600
# 0
# Statut HTTP reçu: 200
# EUW1_7295748515
# Game N° 8
# EUW1_7295748515
# 1
# Statut HTTP reçu: 200
# EUW1_7295657807
# Game N° 9
# EUW1_7295657807
# 1
# Statut HTTP reçu: 200
# EUW1_7295619464
# Game N° 10
# EUW1_7295619464
# 1
# Statut HTTP reçu: 200
# EUW1_7295555998
# Game N° 11
# EUW1_7295555998
# 0
# Statut HTTP reçu: 200
# EUW1_7295523560
# Game N° 12
# EUW1_7295523560
# 1
# ...
